# %%
import pandas as pd

# %%
df = pd.read_csv('data/data.csv')

# %%
pd.set_option("display.max_rows", 6)

# %%
df
# Out:
#      SerialNumber Gender  SecundaryEducationPercent SecundaryBoardEducation  \
# 0               1      M                      67.00                  Others
# 1               2      M                      79.33                 Central
# 2               3      M                      65.00                 Central
# ..            ...    ...                        ...                     ...
# 212           213      M                      67.00                  Others
# 213           214      F                      74.00                  Others
# 214           215      M                      62.00                 Central
#
#      HigherSecondaryPercent HigherBoardEducation Specialization  \
# 0                     91.00               Others       Commerce
# 1                     78.33               Others        Science
# 2                     68.00              Central           Arts
# ..                      ...                  ...            ...
# ...
